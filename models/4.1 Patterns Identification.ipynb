# %% [markdown]
# # Back propagation patterns identifying

# %% [markdown]
# On approach of building market behaviour model during trading session.
#
# In details by the link: [BackPropagationAlgo](https://docs.google.com/document/d/1PYcn-0E_Ar2rbRAFCFSPiU_bhZEuU25OVM2tHC8tRsk/edit#)
#
# For purposes of more flexible patterns describing it can be useful to introduce additional extremums labels: up high (UH), down high (DH), up low (UL) and down low (DL). They are marked by red on pic below. We could catch more detailed information about patterns.

# %% [markdown]
# ![Back%20Propagation%20Extremums%20Marking.png](attachment:Back%20Propagation%20Extremums%20Marking.png)
